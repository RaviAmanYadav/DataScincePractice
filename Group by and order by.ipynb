# %%
import pandas as pd

# %%
df=pd.read_csv('./Data/drinks.csv')

# %%
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
df.isnull().sum()
# Out:
# country                          0
# beer_servings                    0
# spirit_servings                  0
# wine_servings                    0
# total_litres_of_pure_alcohol     0
# continent                       23
# dtype: int64

# %%
x=df.groupby("continent")
x.first()
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# continent
# AF             Algeria             25                0             14
# AS         Afghanistan              0                0              0
# EU             Albania             89              132             54
# OC           Australia            261               72            212
# SA           Argentina            193               25            221
#
#            total_litres_of_pure_alcohol
# continent
# AF                                  0.7
# AS                                  0.0
# EU                                  4.9
# OC                                 10.4
# SA                                  8.3

# %%
x.get_group("AF")
# Out:
#                       country  beer_servings  spirit_servings  wine_servings  \
# 2                     Algeria             25                0             14
# 4                      Angola            217               57             45
# 18                      Benin             34                4             13
# 22                   Botswana            173               35             35
# 26               Burkina Faso             25                7              7
# 27                    Burundi             88                0              0
# 28              Cote d'Ivoire             37                1              7
# 29                 Cabo Verde            144               56             16
# 31                   Cameroon            147                1              4
# 33   Central African Republic             17                2              1
# 34                       Chad             15                1              1
# ...

# %%
var=df.groupby(["continent","country"])
var.first()
# Out:
#                         beer_servings  spirit_servings  wine_servings  \
# continent country
# AF        Algeria                  25                0             14
#           Angola                  217               57             45
#           Benin                    34                4             13
#           Botswana                173               35             35
#           Burkina Faso             25                7              7
# ...                               ...              ...            ...
# SA        Paraguay                213              117             74
#           Peru                    163              160             21
#           Suriname                128              178              7
#           Uruguay                 115               35            220
#           Venezuela               333              100              3
#
#                         total_litres_of_pure_alcohol
# continent country
# ...

# %%
df.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
# what is the total wine serving for the asia continent
df.groupby("continent").agg({"wine_servings":"sum"})
# Out:
#            wine_servings
# continent
# AF                   862
# AS                   399
# EU                  6400
# OC                   570
# SA                   749

# %%
(x.get_group("AS")).sum()
# Out:
# country                         AfghanistanBahrainBangladeshBhutanBruneiCambod...
# beer_servings                                                                1630
# spirit_servings                                                              2677
# wine_servings                                                                 399
# total_litres_of_pure_alcohol                                                 95.5
# continent                       ASASASASASASASASASASASASASASASASASASASASASASAS...
# dtype: object

# %%
df.groupby("continent").sum()
# Out:
#                                                      country  beer_servings  \
# continent
# AF         AlgeriaAngolaBeninBotswanaBurkina FasoBurundiC...           3258
# AS         AfghanistanBahrainBangladeshBhutanBruneiCambod...           1630
# EU         AlbaniaAndorraArmeniaAustriaAzerbaijanBelarusB...           8720
# OC         AustraliaCook IslandsFijiKiribatiMarshall Isla...           1435
# SA         ArgentinaBoliviaBrazilChileColombiaEcuadorGuya...           2101
#
#            spirit_servings  wine_servings  total_litres_of_pure_alcohol
# continent
# AF                     866            862                         159.4
# AS                    2677            399                          95.5
# EU                    5965           6400                         387.8
# OC                     935            570                          54.1
# SA                    1377            749                          75.7

# %%
# sum and average wine serving for "AS"
df.groupby("continent").agg({"wine_servings":["sum","mean"]})
# Out:
#           wine_servings
#                     sum        mean
# continent
# AF                  862   16.264151
# AS                  399    9.068182
# EU                 6400  142.222222
# OC                  570   35.625000
# SA                  749   62.416667

# %%
df.groupby("continent").sum()
# Out:
#                                                      country  beer_servings  \
# continent
# AF         AlgeriaAngolaBeninBotswanaBurkina FasoBurundiC...           3258
# AS         AfghanistanBahrainBangladeshBhutanBruneiCambod...           1630
# EU         AlbaniaAndorraArmeniaAustriaAzerbaijanBelarusB...           8720
# OC         AustraliaCook IslandsFijiKiribatiMarshall Isla...           1435
# SA         ArgentinaBoliviaBrazilChileColombiaEcuadorGuya...           2101
#
#            spirit_servings  wine_servings  total_litres_of_pure_alcohol
# continent
# AF                     866            862                         159.4
# AS                    2677            399                          95.5
# EU                    5965           6400                         387.8
# OC                     935            570                          54.1
# SA                    1377            749                          75.7

# %%
df.groupby("continent").agg({"beer_servings":["sum","mean"]})
# Out:
#           beer_servings
#                     sum        mean
# continent
# AF                 3258   61.471698
# AS                 1630   37.045455
# EU                 8720  193.777778
# OC                 1435   89.687500
# SA                 2101  175.083333
