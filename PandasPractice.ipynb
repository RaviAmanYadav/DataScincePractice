# %%
import pandas as pd

# %%
loan = pd.read_csv('./Data/loan_data_set.csv')

# %%
loan
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan.shape
# Out:
# (614, 13)

# %%
s1 = pd.Series(data=[10, 20, 30, 40, 50], index=["Maths", "English", "Science", "Social Studies", "Computer Science"])
s2 = pd.Series(data=[100, 200, 300, 400, 500], index=["Maths", "English", "Science", "Social Studies", "Computer Science"])

# %%
print(s1)
# Out:
# Maths               10
# English             20
# Science             30
# Social Studies      40
# Computer Science    50
# dtype: int64

# %%
print(s2)
# Out:
# Maths               100
# English             200
# Science             300
# Social Studies      400
# Computer Science    500
# dtype: int64

# %%
s1["Computer Science"]
# Out:
# 50

# %%
s1.size
# Out:
# 5

# %%
s1.shape
# Out:
# (5,)

# %%
s1.dtypes
# Out:
# dtype('int64')

# %%
df1 = pd.DataFrame(data={"Section 1" : [99, 100, 87, 86, 90], "Section 2" : [90, 80, 90, 70, 60]}, index = ["Maths", "English", "Science", "Socail Studies", "Computer Science"])

# %%
df1
# Out:
#                   Section 1  Section 2
# Maths                    99         90
# English                 100         80
# Science                  87         90
# Socail Studies           86         70
# Computer Science         90         60

# %%
loan = pd.read_csv("./Data/loan_data_set.csv")

# %%
loan.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
loan.index = loan["Loan_ID"]

# %%
loan = loan.reset_index(drop=True)

# %%
loan.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df = pd.DataFrame({'ID' : [1, 2, 3, 4, 5], 'Name' : ["Aman", "Anchal", "Mayank", "Pushpa", "Rama Dhar"]})

# %%
df
# Out:
#    ID       Name
# 0   1       Aman
# 1   2     Anchal
# 2   3     Mayank
# 3   4     Pushpa
# 4   5  Rama Dhar

# %%
loan.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
loan.loc[:30,["Married", "Education", "Self_Employed"]]
# Out:
#    Married     Education Self_Employed
# 0       No      Graduate            No
# 1      Yes      Graduate            No
# 2      Yes      Graduate           Yes
# 3      Yes  Not Graduate            No
# 4       No      Graduate            No
# 5      Yes      Graduate           Yes
# 6      Yes  Not Graduate            No
# 7      Yes      Graduate            No
# 8      Yes      Graduate            No
# 9      Yes      Graduate            No
# 10     Yes      Graduate            No
# 11     Yes      Graduate           NaN
# 12     Yes      Graduate            No
# 13      No      Graduate            No
# 14     Yes      Graduate            No
# 15      No      Graduate            No
# 16      No  Not Graduate            No
# 17      No      Graduate            No
# 18     Yes  Not Graduate            No
# 19     Yes      Graduate           NaN
# 20     Yes  Not Graduate            No
# 21     Yes      Graduate            No
# 22     Yes  Not Graduate            No
# ...

# %%
loan1 = loan.copy()

# %%
loan1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan1.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
loan1.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
loan1.describe(include = "object")
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        614    601     611        599       614           582
# unique       614      2       2          4         2             2
# top     LP001002   Male     Yes          0  Graduate            No
# freq           1    489     398        345       480           500
#
#        Property_Area Loan_Status
# count            614         614
# unique             3           2
# top        Semiurban           Y
# freq             233         422

# %%
loan1.describe(include = "all")
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        614    601     611        599       614           582
# unique       614      2       2          4         2             2
# top     LP001002   Male     Yes          0  Graduate            No
# freq           1    489     398        345       480           500
# mean         NaN    NaN     NaN        NaN       NaN           NaN
# std          NaN    NaN     NaN        NaN       NaN           NaN
# min          NaN    NaN     NaN        NaN       NaN           NaN
# 25%          NaN    NaN     NaN        NaN       NaN           NaN
# 50%          NaN    NaN     NaN        NaN       NaN           NaN
# 75%          NaN    NaN     NaN        NaN       NaN           NaN
# max          NaN    NaN     NaN        NaN       NaN           NaN
#
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count        614.000000         614.000000  592.000000         600.00000
# ...

# %%
loan1["Loan_Status"].value_counts()
# Out:
# Loan_Status
# Y    422
# N    192
# Name: count, dtype: int64

# %%
# In normalize the data will be within 0 and 1
loan1["Loan_Status"].value_counts(normalize = True) * 100
# Out:
# Loan_Status
# Y    68.729642
# N    31.270358
# Name: proportion, dtype: float64

# %%
loan1["Loan_Status"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Loan_Status'>

# %%
loan1["Loan_Status"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
loan1.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
loan["ApplicantIncome"].describe()
# Out:
# count      614.000000
# mean      5403.459283
# std       6109.041673
# min        150.000000
# 25%       2877.500000
# 50%       3812.500000
# 75%       5795.000000
# max      81000.000000
# Name: ApplicantIncome, dtype: float64

# %%
loan1["ApplicantIncome"].plot(kind = "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
loan1["ApplicantIncome"].plot(kind = "kde")
# Out:
# <Axes: ylabel='Density'>

# %%
loan1.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
# how many female got the loan
pd.crosstab(loan["Loan_Status"], loan["Gender"], margins=True)
# Out:
# Gender       Female  Male  All
# Loan_Status
# N                37   150  187
# Y                75   339  414
# All             112   489  601

# %%
pd.crosstab(loan['Loan_Status'], loan['Gender'], normalize = 'index') * 100
# Out:
# Gender          Female       Male
# Loan_Status
# N            19.786096  80.213904
# Y            18.115942  81.884058

# %%
loan1.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
# loan1 = loan1.drop(['Loan_ID'], axis = 1)

# %%
loan1.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
# bivarate numerical anaysis
x = loan.loc[:,["ApplicantIncome", 'CoapplicantIncome', 'LoanAmount', 'Credit_History']]

# %%
x
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Credit_History
# 0               5849                0.0         NaN             1.0
# 1               4583             1508.0       128.0             1.0
# 2               3000                0.0        66.0             1.0
# 3               2583             2358.0       120.0             1.0
# 4               6000                0.0       141.0             1.0
# ..               ...                ...         ...             ...
# 609             2900                0.0        71.0             1.0
# 610             4106                0.0        40.0             1.0
# 611             8072              240.0       253.0             1.0
# 612             7583                0.0       187.0             1.0
# 613             4583                0.0       133.0             0.0
#
# [614 rows x 4 columns]

# %%
x = x.corr(method = 'pearson', min_periods = 1)
x
# Out:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.116605    0.570909
# CoapplicantIncome        -0.116605           1.000000    0.188619
# LoanAmount                0.570909           0.188619    1.000000
# Credit_History           -0.014715          -0.002056   -0.008433
#
#                    Credit_History
# ApplicantIncome         -0.014715
# CoapplicantIncome       -0.002056
# LoanAmount              -0.008433
# Credit_History           1.000000

# %%
# heatmap
import seaborn as sns

# %%
sns.heatmap(x, cmap = "Purples", annot = True)
# Out:
# <Axes: >

# %%
#bivariate combination of numerical and categorical feature.
loan1.boxplot(column="ApplicantIncome",by="Credit_History")
# Out:
# <Axes: title={'center': 'ApplicantIncome'}, xlabel='Credit_History'>

# %% [markdown]
# # Data Cleaning

# %%
print(loan1.duplicated().sum())
# Out:
# 0

# %%
# if we are having duplicate value
loan1 = loan1.drop_duplicates()

# %%
loan1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
loan1.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
loan1["Self_Employed"] = loan1["Self_Employed"].fillna(loan1["Self_Employed"].mode()[0])

# %%
loan1.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
loan1["Credit_History"].describe()
# Out:
# count    564.000000
# mean       0.842199
# std        0.364878
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: Credit_History, dtype: float64

# %%
x = loan1["Credit_History"].astype("object")

# %%
x.mode()
# Out:
# 0    1.0
# Name: Credit_History, dtype: object

# %%
loan1["LoanAmount"].describe()
# Out:
# count    592.000000
# mean     146.412162
# std       85.587325
# min        9.000000
# 25%      100.000000
# 50%      128.000000
# 75%      168.000000
# max      700.000000
# Name: LoanAmount, dtype: float64

# %%
loan1["LoanAmount"].median()
# Out:
# 128.0

# %%
loan1["LoanAmount"] = loan1["LoanAmount"].fillna(loan1["LoanAmount"].median())

# %%
loan1["LoanAmount"].describe()
# Out:
# count    614.000000
# mean     145.752443
# std       84.107233
# min        9.000000
# 25%      100.250000
# 50%      128.000000
# 75%      164.750000
# max      700.000000
# Name: LoanAmount, dtype: float64

# %% [markdown]
# # Feature Engginering

# %%
loan3 = pd.read_csv("./Data/loan_data_set.csv")

# %%
loan3
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan3["total_income"]=loan3["ApplicantIncome"]+loan3["CoapplicantIncome"]

# %%
loan3.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status  total_income
# 0             1.0         Urban           Y        5849.0
# ...

# %%
loan3["LoanAmount"]=loan3["LoanAmount"].fillna(loan3["LoanAmount"].median())

# %%
loan3["LTI"]=(loan3["LoanAmount"]/loan3["total_income"])*100

# %%
loan3.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status  total_income       LTI
# 0             1.0         Urban           Y        5849.0  2.188408
# ...

# %%
loan3["LTI"].describe()
# Out:
# count    614.000000
# mean       2.387679
# std        0.870716
# min        0.252292
# 25%        1.922055
# 50%        2.412921
# 75%        2.815802
# max        8.271164
# Name: LTI, dtype: float64

# %%
def income(var):
    if var<5000:
        return "Low Income grp"
    elif var>=5000 and var<1000:
        return "mid income grp"
    else:
        return "High income grp"

# %%
loan3["Binning"]=loan3["total_income"].apply(income)

# %%
loan3.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# ...

# %%
loan3["LoanAmount"].describe()
# Out:
# count    614.000000
# mean     145.752443
# std       84.107233
# min        9.000000
# 25%      100.250000
# 50%      128.000000
# 75%      164.750000
# max      700.000000
# Name: LoanAmount, dtype: float64

# %%
# column for stability and unstability
def stable(var):
    if (var["Married"]=="Yes") & (var["Education"]=="Graduate") & (var["Self_Employed"]=="No"):
        return "stable"
    else:
        return "unstable"

# %%
loan3["Stability"]=loan3.apply(stable,axis=1)

# %%
loan3
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# # Filtering of the data loc and iloc

# %%
loan3.loc[loan3["Education"] == "Graduate"]
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 0    LP001002    Male      No          0  Graduate            No
# 1    LP001003    Male     Yes          1  Graduate            No
# 2    LP001005    Male     Yes          0  Graduate           Yes
# 4    LP001008    Male      No          0  Graduate            No
# 5    LP001011    Male     Yes          2  Graduate           Yes
# ..        ...     ...     ...        ...       ...           ...
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0       128.0             360.0
# ...

# %%
loan3.loc[(loan3["Education"]=="Graduate")&(loan3["Married"]=="Yes")]
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 1    LP001003   Male     Yes          1  Graduate            No
# 2    LP001005   Male     Yes          0  Graduate           Yes
# 5    LP001011   Male     Yes          2  Graduate           Yes
# 7    LP001014   Male     Yes         3+  Graduate            No
# 8    LP001018   Male     Yes          2  Graduate            No
# ..        ...    ...     ...        ...       ...           ...
# 606  LP002961   Male     Yes          1  Graduate            No
# 608  LP002974   Male     Yes          0  Graduate            No
# 610  LP002979   Male     Yes         3+  Graduate            No
# 611  LP002983   Male     Yes          1  Graduate            No
# 612  LP002984   Male     Yes          2  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583             1508.0       128.0             360.0
# ...

# %%
for i in loan.columns:
    print(i)
# Out:
# Loan_ID
# Gender
# Married
# Dependents
# Education
# Self_Employed
# ApplicantIncome
# CoapplicantIncome
# LoanAmount
# Loan_Amount_Term
# Credit_History
# Property_Area
# Loan_Status

# %%
for i in enumerate (loan.columns):
    print(i)
# Out:
# (0, 'Loan_ID')
# (1, 'Gender')
# (2, 'Married')
# (3, 'Dependents')
# (4, 'Education')
# (5, 'Self_Employed')
# (6, 'ApplicantIncome')
# (7, 'CoapplicantIncome')
# (8, 'LoanAmount')
# (9, 'Loan_Amount_Term')
# (10, 'Credit_History')
# (11, 'Property_Area')
# (12, 'Loan_Status')

# %%
loan.iloc[150:201,5:10]
# Out:
#     Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 150            No             6277                0.0       118.0
# 151           Yes             2577             3750.0       152.0
# 152            No             9166                0.0       244.0
# 153            No             2281                0.0       113.0
# 154            No             3254                0.0        50.0
# 155            No            39999                0.0       600.0
# 156            No             6000                0.0       160.0
# 157            No             9538                0.0       187.0
# 158           NaN             2980             2083.0       120.0
# 159            No             4583             5625.0       255.0
# 160            No             1863             1041.0        98.0
# 161            No             7933                0.0       275.0
# 162            No             3089             1280.0       121.0
# ...

# %% [markdown]
# # Group by and order by

# %%
loan1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
var=loan1.groupby(["Married","Gender"])
var.first()
# Out:
#                  Loan_ID Dependents Education Self_Employed  ApplicantIncome  \
# Married Gender
# No      Female  LP001036          0  Graduate            No             3510
#         Male    LP001002          0  Graduate            No             5849
# Yes     Female  LP001112          0  Graduate            No             3667
#         Male    LP001003          1  Graduate            No             4583
#
#                 CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Married Gender
# No      Female                0.0        76.0             360.0
#         Male                  0.0       128.0             360.0
# Yes     Female             1459.0       144.0             360.0
#         Male               1508.0       128.0             360.0
#
#                 Credit_History Property_Area Loan_Status
# Married Gender
# No      Female             0.0         Urban           N
#         Male               1.0         Urban           Y
# ...

# %%
var=loan1.groupby(["Married","Gender"])

# %%
print(loan1.columns)
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
loan1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
# find the average loan amount for the female and maxium applicant income female
loan1[loan1["Gender"]=="Female"].agg({"LoanAmount":"mean","ApplicantIncome":"max"})
# Out:
# LoanAmount           126.732143
# ApplicantIncome    19484.000000
# dtype: float64

# %%
pd.Series({
    "AvgLoanAmount_Female":loan1[loan1["Gender"]=="Female"]["LoanAmount"].mean(),
    "MaxApplicantIncome_Married":loan1[loan1["Married"]=="Yes"]["ApplicantIncome"].max()
})
# Out:
# AvgLoanAmount_Female            126.732143
# MaxApplicantIncome_Married    81000.000000
# dtype: float64

# %%
w=loan1.groupby("Gender").agg({"LoanAmount":"mean","ApplicantIncome":"max"})
w
# Out:
#         LoanAmount  ApplicantIncome
# Gender
# Female  126.732143            19484
# Male    148.439673            81000

# %%
w.reset_index()
# Out:
#    Gender  LoanAmount  ApplicantIncome
# 0  Female  126.732143            19484
# 1    Male  148.439673            81000

# %%
w=w.iloc[0:1,:]
w
# Out:
#         LoanAmount  ApplicantIncome
# Gender
# Female  126.732143            19484

# %%
w=w.rename(columns={"LoanAmount":"Mean_LoanAmount","ApplicantIncome":"Maximum_ApplicantIncome"})
w
# Out:
#         Mean_LoanAmount  Maximum_ApplicantIncome
# Gender
# Female       126.732143                    19484

# %%
loan1.sort_values(by="ApplicantIncome").head()
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 216  LP001722    Male     Yes          0      Graduate            No
# 468  LP002502  Female     Yes          2  Not Graduate            No
# 600  LP002949  Female      No         3+      Graduate            No
# 500  LP002603  Female      No          0      Graduate            No
# 188  LP001644     NaN     Yes          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 216              150             1800.0       135.0             360.0
# 468              210             2917.0        98.0             360.0
# 600              416            41667.0       350.0             180.0
# 500              645             3683.0       113.0             480.0
# 188              674             5296.0       168.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 216             1.0         Rural           N
# ...

# %%
loan1.sort_values(by="LoanAmount",ascending=False)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 171  LP001585     NaN     Yes         3+      Graduate            No
# 130  LP001469    Male      No          0      Graduate           Yes
# 561  LP002813  Female     Yes          1      Graduate           Yes
# 155  LP001536    Male     Yes         3+      Graduate            No
# 369  LP002191    Male     Yes          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 555  LP002792    Male     Yes          1      Graduate            No
# 94   LP001325    Male      No          0  Not Graduate            No
# 133  LP001482    Male     Yes          0      Graduate           Yes
# 14   LP001030    Male     Yes          2      Graduate            No
# 568  LP002840  Female      No          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
dt=pd.read_csv("./Data/air.csv")
dt
# Out:
#         city country                   date.utc            location parameter  \
# 0      Paris      FR  2019-06-21 00:00:00+00:00             FR04014       no2
# 1      Paris      FR  2019-06-20 23:00:00+00:00             FR04014       no2
# 2      Paris      FR  2019-06-20 22:00:00+00:00             FR04014       no2
# 3      Paris      FR  2019-06-20 21:00:00+00:00             FR04014       no2
# 4      Paris      FR  2019-06-20 20:00:00+00:00             FR04014       no2
# ...      ...     ...                        ...                 ...       ...
# 2063  London      GB  2019-05-07 06:00:00+00:00  London Westminster       no2
# 2064  London      GB  2019-05-07 04:00:00+00:00  London Westminster       no2
# 2065  London      GB  2019-05-07 03:00:00+00:00  London Westminster       no2
# 2066  London      GB  2019-05-07 02:00:00+00:00  London Westminster       no2
# 2067  London      GB  2019-05-07 01:00:00+00:00  London Westminster       no2
#
#       value   unit
# ...

# %%
dt.dtypes
# Out:
# city          object
# country       object
# date.utc      object
# location      object
# parameter     object
# value        float64
# unit          object
# dtype: object

# %%
dt=dt.rename(columns={"date.utc":"date_time"})

# %%
dt.dtypes
# Out:
# city          object
# country       object
# date_time     object
# location      object
# parameter     object
# value        float64
# unit          object
# dtype: object

# %%
dt["date_time"]=pd.to_datetime(dt["date_time"])

# %%
dt.dtypes
# Out:
# city                      object
# country                   object
# date_time    datetime64[ns, UTC]
# location                  object
# parameter                 object
# value                    float64
# unit                      object
# dtype: object

# %%
dt["date_time"].min()
# Out:
# Timestamp('2019-05-07 01:00:00+0000', tz='UTC')

# %%
dt["date_time"].max()
# Out:
# Timestamp('2019-06-21 00:00:00+0000', tz='UTC')

# %%
dt["date_time"].max()-dt["date_time"].min()
# Out:
# Timedelta('44 days 23:00:00')

# %%
dt["date_time"].dt.month
# Out:
# 0       6
# 1       6
# 2       6
# 3       6
# 4       6
#        ..
# 2063    5
# 2064    5
# 2065    5
# 2066    5
# 2067    5
# Name: date_time, Length: 2068, dtype: int32

# %%
# how many entry do we have for may
dt["date_time"].dt.month.value_counts()
# Out:
# date_time
# 5    1256
# 6     812
# Name: count, dtype: int64

# %%
loan1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
# top 5 loan amount
loan1.sort_values(by="LoanAmount",ascending=False).head()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 171  LP001585     NaN     Yes         3+  Graduate            No
# 130  LP001469    Male      No          0  Graduate           Yes
# 561  LP002813  Female     Yes          1  Graduate           Yes
# 155  LP001536    Male     Yes         3+  Graduate            No
# 369  LP002191    Male     Yes          0  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 171            51763                0.0       700.0             300.0
# 130            20166                0.0       650.0             480.0
# 561            19484                0.0       600.0             360.0
# 155            39999                0.0       600.0             180.0
# 369            19730             5266.0       570.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 171             1.0         Urban           Y
# 130             NaN         Urban           Y
# ...

# %%
loan1.pivot(index="Loan_ID",columns="Education",values="LoanAmount")
# Out:
# Education  Graduate  Not Graduate
# Loan_ID
# LP001002      128.0           NaN
# LP001003      128.0           NaN
# LP001005       66.0           NaN
# LP001006        NaN         120.0
# LP001008      141.0           NaN
# ...             ...           ...
# LP002978       71.0           NaN
# LP002979       40.0           NaN
# LP002983      253.0           NaN
# LP002984      187.0           NaN
# LP002990      133.0           NaN
#
# [614 rows x 2 columns]
